# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('universities V1.1.csv')

# %%
data
# Out:
#       rank                                      name        location  \
# 0        1                        Harvard University             USA
# 1        2     Massachusetts Institute of Technology             USA
# 2        3                       Stanford University             USA
# 3        4                   University of Cambridge  United Kingdom
# 4        5                      University of Oxford  United Kingdom
# ...    ...                                       ...             ...
# 1995  1996         Polytechnic Institute of Bragança        Portugal
# 1996  1997            Federal University of Maranhão          Brazil
# 1997  1998  Autonomous University of Baja California          Mexico
# 1998  1999              American University in Cairo           Egypt
# 1999  2000                        Kyonggi University     South Korea
#
#       national_rank quality_of_education alumni_employment quality_of_faculty  \
# ...

# %%
data.shape
# Out:
# (2000, 10)

# %%
data.columns
# Out:
# Index(['rank', 'name', 'location', 'national_rank', 'quality_of_education',
#        'alumni_employment', 'quality_of_faculty', 'research_performance',
#        'score', 'domain'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   rank                  2000 non-null   int64
#  1   name                  2000 non-null   object
#  2   location              2000 non-null   object
#  3   national_rank         2000 non-null   int64
#  4   quality_of_education  2000 non-null   object
#  5   alumni_employment     2000 non-null   object
#  6   quality_of_faculty    2000 non-null   object
#  7   research_performance  2000 non-null   object
#  8   score                 2000 non-null   float64
#  9   domain                2000 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 156.4+ KB

# %% [markdown]
# print("2ooonb")

# %%
data.describe()
# Out:
#               rank  national_rank        score
# count  2000.000000     2000.00000  2000.000000
# mean   1000.500000       68.06550    71.636000
# std     577.494589       84.29192     5.068522
# min       1.000000        1.00000    65.800000
# 25%     500.750000       10.00000    67.700000
# 50%    1000.500000       33.00000    70.300000
# 75%    1500.250000       87.00000    74.200000
# max    2000.000000      357.00000   100.000000

# %%
data.isnull().sum()
# Out:
# rank                    0
# name                    0
# location                0
# national_rank           0
# quality_of_education    0
# alumni_employment       0
# quality_of_faculty      0
# research_performance    0
# score                   0
# domain                  0
# dtype: int64

# %%
data
# Out:
#       rank                                      name        location  \
# 0        1                        Harvard University             USA
# 1        2     Massachusetts Institute of Technology             USA
# 2        3                       Stanford University             USA
# 3        4                   University of Cambridge  United Kingdom
# 4        5                      University of Oxford  United Kingdom
# ...    ...                                       ...             ...
# 1995  1996         Polytechnic Institute of Bragança        Portugal
# 1996  1997            Federal University of Maranhão          Brazil
# 1997  1998  Autonomous University of Baja California          Mexico
# 1998  1999              American University in Cairo           Egypt
# 1999  2000                        Kyonggi University     South Korea
#
#       national_rank quality_of_education alumni_employment quality_of_faculty  \
# ...

# %%
data['quality_of_education'] = data['quality_of_education'].replace('-', 0.0).astype(float)
data['alumni_employment'] = data['alumni_employment'].replace('-', 0.0).astype(float)
data['quality_of_faculty'] = data['quality_of_faculty'].replace('-', 0.0).astype(float)
data['research_performance'] = data['research_performance'].replace('-', 0.0).astype(float)

# %%
data
# Out:
#       rank                                      name        location  \
# 0        1                        Harvard University             USA
# 1        2     Massachusetts Institute of Technology             USA
# 2        3                       Stanford University             USA
# 3        4                   University of Cambridge  United Kingdom
# 4        5                      University of Oxford  United Kingdom
# ...    ...                                       ...             ...
# 1995  1996         Polytechnic Institute of Bragança        Portugal
# 1996  1997            Federal University of Maranhão          Brazil
# 1997  1998  Autonomous University of Baja California          Mexico
# 1998  1999              American University in Cairo           Egypt
# 1999  2000                        Kyonggi University     South Korea
#
#       national_rank  quality_of_education  alumni_employment  \
# 0                 1                   3.0                1.0
# ...

# %%
data['location'].unique()
# Out:
# array(['USA', 'United Kingdom', 'Japan', 'France', 'Canada',
#        'Switzerland', 'South Korea', 'Denmark', 'Sweden', 'Germany',
#        'Israel', 'China', 'Australia', 'Netherlands', 'Norway', 'Taiwan',
#        'Singapore', 'Brazil', 'Finland', 'Italy', 'Belgium', 'Spain',
#        'Russia', 'Portugal', 'Austria', 'Ireland', 'Czech Republic',
#        'New Zealand', 'Greece', 'South Africa', 'Mexico', 'Saudi Arabia',
#        'Serbia', 'Argentina', 'Chile', 'Poland', 'Slovenia', 'Iran',
#        'Malaysia', 'India', 'Thailand', 'Estonia', 'Croatia', 'Iceland',
#        'Egypt', 'Turkey', 'Hungary', 'Slovak Republic', 'Lithuania',
#        'Lebanon', 'Cyprus', 'Colombia', 'Pakistan', 'Armenia', 'Belarus',
#        'Romania', 'Bulgaria', 'Georgia', 'Luxembourg', 'Uruguay',
#        'Uganda', 'Tunisia', 'United Arab Emirates', 'Qatar', 'Morocco',
#        'Philippines', 'Ethiopia', 'Nigeria', 'Kuwait', 'Cameroon',
# ...

# %%
data['location'].value_counts().head(10)
# Out:
# USA               357
# China             267
# Japan             126
# United Kingdom     95
# France             82
# Germany            70
# Italy              66
# India              64
# South Korea        61
# Brazil             57
# Name: location, dtype: int64

# %%
plt.figure(figsize=(10,8))
data['location'].value_counts().head(40).plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=data['national_rank'].head(10),y=data['research_performance'].head(10))
plt.xticks(rotation=60);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19452/3186644240.py in <module>
# ----> 1 sns.barplot(x=data['national_rank'].head(10),y=data['research_performance'].head(10)).title('sdgdshdjhd')
#       2 plt.xticks(rotation=60);
#
# TypeError: 'Text' object is not callable

# %%
sns.violinplot(data['location'].head(),  data['score'].head())
# Out:
# C:\Users\Polos\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='location', ylabel='score'>

# %% [markdown]
# # AFRICA

# %%
africa=['Ghana','Nigeria','Togo','South Africa','Algeria','Kenya','Benin','Angola','Ethopia']


africa=data.loc[data['location'].isin(africa)]

# %%
africa
# Out:
#       rank                                               name      location  \
# 267    268                            University of Cape Town  South Africa
# 274    275                    University of the Witwatersrand  South Africa
# 428    429                            Stellenbosch University  South Africa
# 476    477                        University of KwaZulu-Natal  South Africa
# 577    578                             University of Pretoria  South Africa
# 705    706                         University of Johannesburg  South Africa
# 921    922                              North-West University  South Africa
# 1157  1158                         University of Western Cape  South Africa
# 1162  1163                               University of Ibadan       Nigeria
# 1199  1200                       University of the Free State  South Africa
# 1294  1295                                  Rhodes University  South Africa
# ...

# %%
usa=data[data['location']=='USA']

# %%
usa
# Out:
#       rank                                   name location  national_rank  \
# 0        1                     Harvard University      USA              1
# 1        2  Massachusetts Institute of Technology      USA              2
# 2        3                    Stanford University      USA              3
# 5        6                    Columbia University      USA              4
# 6        7                   Princeton University      USA              5
# ...    ...                                    ...      ...            ...
# 1960  1961                      Lafayette College      USA            353
# 1970  1971                           Reed College      USA            354
# 1973  1974                  SUNY Maritime College      USA            355
# 1988  1989                St. Lawrence University      USA            356
# 1993  1994                         The New School      USA            357
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# ...

# %%
sns.heatmap(data.corr(), annot=True, cmap='jet')
plt.show()
